# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
df_ffa_p1_c1_t1 = pd.read_csv('logs/experiment/pso_ffa/ffa/ffa_weight_p1_c1_t1_Ndays_30epoch_tour_20230429-190627.csv')
df_ffa_p1_c0_t0 = pd.read_csv('logs/experiment/pso_ffa/ffa/ffa_weight_p1_c0_t0_Ndays_30epoch_tour_20230429-190628.csv')
df_ffa_p0_c1_t0 = pd.read_csv('logs/experiment/pso_ffa/ffa/ffa_weight_p0_c1_t0_Ndays_30epoch_tour_20230429-190629.csv')
df_ffa_p0_c0_t1 = pd.read_csv('logs/experiment/pso_ffa/ffa/ffa_weight_p0_c0_t1_Ndays_30epoch_tour_20230429-190630.csv')

df_pso_p1_c1_t1 = pd.read_csv('logs/experiment/pso_ffa/pso/pso_weight_p1_c1_t1_Ndays_30epoch_tour_20230429-185941.csv')
df_pso_p1_c0_t0 = pd.read_csv('logs/experiment/pso_ffa/pso/pso_weight_p1_c0_t0_Ndays_30epoch_tour_20230429-185941.csv')
df_pso_p0_c1_t0 = pd.read_csv('logs/experiment/pso_ffa/pso/pso_weight_p0_c1_t0_Ndays_30epoch_tour_20230429-185941.csv')
df_pso_p0_c0_t1 = pd.read_csv('logs/experiment/pso_ffa/pso/pso_weight_p0_c0_t1_Ndays_30epoch_tour_20230429-185942.csv')
key_time = "avg_time_process"
key_node = "avg_node"
key_day = "avg_day"
key_fitness = "avg_fitness"
key_score = "param_score"
sliced = 0

# %%
def create_df(df_all, df_all_name):
    df_all_sub_name = [key_node, key_day, key_time, key_score] #key_fitness
    tmp_col = []
    tmp_sub_col = []
    for n in df_all_name:
        for sn in df_all_sub_name:
            tmp_col.append(n)
            tmp_sub_col.append(sn)

    col_df_all = [
        tmp_col,
        tmp_sub_col
    ]
    tmp_df_all = []
    for v in df_all[0]["max_tour"]:
        tmp_df_all.append([])

    for i, v in enumerate(df_all, start=1):
        for a, b in enumerate(df_all_sub_name):
            for t in range(len(tmp_df_all)):
                tmp_df_all[t].append(v[b][t])

    df_res = pd.DataFrame(tmp_df_all, columns=col_df_all, index=list(df_all[0]["max_tour"].values))
    df_res.index.name = "max_tour"
    display(df_res)
    display(df_res.describe())
    return df_res

# %%
df_all = [df_ffa_p1_c1_t1, df_pso_p1_c1_t1]
df_all_name = ["ffa", "pso"]
df_res = create_df(df_all, df_all_name)
# Out:
#               ffa                                           pso          \
#          avg_node avg_day avg_time_process param_score avg_node avg_day
# max_tour
# 5             4.0     1.0         7.412486    0.750000      4.0     1.0
# 15           14.6     2.0        22.272959    0.733274     14.0     2.0
# 30           28.8     4.8        68.546001    0.584448     28.2     4.2
# 45           43.4     7.6       150.380388    0.509496     43.4     7.4
# 60           59.0    10.4       252.580289    0.419625     58.6    10.2
# 75           73.4    13.4       428.991839    0.366816     73.4    13.2
# 100          98.0    18.0       700.635768    0.261804     97.8    17.2
#
#
#          avg_time_process param_score
# max_tour
# 5                0.207953    0.750000
# 15               0.568909    0.729889
# 30               1.659305    0.620114
# 45               3.420267    0.517520
# 60               5.556481    0.444005
# 75               8.635474    0.346640
# ...

# %%
df_all = [df_ffa_p1_c0_t0, df_pso_p1_c0_t0]
df_all_name = ["ffa", "pso"]
df_res = create_df(df_all, df_all_name)
# Out:
#               ffa                                           pso          \
#          avg_node avg_day avg_time_process param_score avg_node avg_day
# max_tour
# 5             4.0     1.0         7.467273    0.750000      4.0     1.0
# 15           13.0     2.0        28.216162    0.730127     13.0     2.0
# 30           29.8     6.0        87.534195    0.480381     29.2     5.0
# 45           44.6     9.6       208.423477    0.473462     44.6     8.2
# 60           59.4    12.4       356.134642    0.453985     59.4    11.0
# 75           74.4    16.2       589.070474    0.416380     74.2    14.4
# 100          98.0    20.0       899.224474    0.319602     98.4    18.4
#
#
#          avg_time_process param_score
# max_tour
# 5                0.221323    0.750000
# 15               0.736982    0.715321
# 30               1.874714    0.502031
# 45               3.871843    0.449240
# 60               6.508683    0.430131
# 75              10.794369    0.407596
# ...

# %%
df_all = [df_ffa_p0_c1_t0, df_pso_p0_c1_t0]
df_all_name = ["ffa", "pso"]
df_res = create_df(df_all, df_all_name)
# Out:
#               ffa                                           pso          \
#          avg_node avg_day avg_time_process param_score avg_node avg_day
# max_tour
# 5             4.0     1.0         7.407742    0.750000      4.0     1.0
# 15           13.0     2.0        26.739853    0.737143     13.0     2.0
# 30           28.0     5.0        79.150042    0.645915     27.6     4.4
# 45           42.4     8.4       176.040393    0.562273     42.4     7.6
# 60           58.2    12.4       335.828920    0.482470     58.6    11.0
# 75           74.0    16.2       505.287044    0.333186     73.4    14.4
# 100          97.8    20.2       808.037977    0.278333     98.2    18.8
#
#
#          avg_time_process param_score
# max_tour
# 5                0.217694    0.750000
# 15               0.712071    0.735533
# 30               1.874128    0.651810
# 45               3.776822    0.560573
# 60               6.227227    0.448924
# 75               9.671252    0.349361
# ...

# %%
df_all = [df_ffa_p0_c0_t1, df_pso_p0_c0_t1]
df_all_name = ["ffa", "pso"]
df_res = create_df(df_all, df_all_name)
# Out:
#               ffa                                           pso          \
#          avg_node avg_day avg_time_process param_score avg_node avg_day
# max_tour
# 5             4.0     1.0         7.403185    0.750000      4.0     1.0
# 15           14.8     2.0        22.147218    0.751616     14.4     2.0
# 30           29.2     4.6        68.346385    0.565130     28.8     4.4
# 45           43.6     7.2       147.518868    0.501930     43.8     7.0
# 60           57.2     9.6       280.253109    0.429446     58.6    10.0
# 75           68.0    11.4       450.631410    0.366074     74.2    13.2
# 100          97.6    16.6       659.696524    0.250000     98.0    17.0
#
#
#          avg_time_process param_score
# max_tour
# 5                0.196220    0.750000
# 15               0.556606    0.732630
# 30               1.626728    0.591572
# 45               3.177773    0.516328
# 60               5.481365    0.454290
# 75               8.478474    0.349591
# ...

# %%
def plot_result(data1, data2, key, ylabel, title):
    data_node = []
    node_columns = [data1[1], data2[1]]
    for i, d1, d2 in zip(
        data1[0]['max_tour'].values, 
        data1[0][key].values,
        data2[0][key].values,
    ):
        data_node.append([i,d1,d2])

    df_node = pd.DataFrame(data_node, columns=["max_tour"]+node_columns)
    df_node.plot(x='max_tour', y=node_columns, kind='line', figsize=(8 ,5))

    plt.title(title)
    plt.xlabel('Number of Destination (Input)')
    plt.ylabel(ylabel)
    plt.legend(node_columns)
    plt.show()

# %%
plot_result([df_ffa_p1_c1_t1, "Firefly Algorithm"], [df_pso_p1_c1_t1,"Particle Swarm Optimization"], key_node, "Number of Destination (Output)", "Number of Destination (Output) of PSO vs. FA with Criteria w1=1, w2=1, w3=1")

# %%
plot_result([df_ffa_p1_c1_t1, "Firefly Algorithm"], [df_pso_p1_c1_t1,"Particle Swarm Optimization"], key_time, "Time (s)", "Running Time of PSO vs. FA with Criteria w1=1, w2=1, w3=1")

# %%
plot_result([df_ffa_p1_c1_t1, "Firefly Algorithm"], [df_pso_p1_c1_t1,"Particle Swarm Optimization"], key_score, "Score", "Score of PSO vs. FA with Criteria w1=1, w2=1, w3=1")

# %%
data_node = []
node_columns = ["avg_node_ffa", "avg_node_pso"]
for i, ffa, pso in zip(
    df_ffa_p1_c1_t1['max_tour'].values, 
    df_ffa_p1_c1_t1[key_node].values,
    df_pso_p1_c1_t1[key_node].values,
):
    data_node.append([i,ffa,pso])

df_node = pd.DataFrame(data_node, columns=["max_tour"]+node_columns)
df_node.plot(x='max_tour', y=node_columns, kind='line', figsize=(8 ,5))

plt.title('Max Tour - Node')
plt.xlabel('max_tour')
plt.ylabel('Avg Node')
plt.legend(node_columns)
plt.show()

# %%
# data_node = []
# node_columns = ["avg_node_ffa", "avg_node_cpso", "avg_node_pso", "avg_node_ffao", "avg_node_ffa", "avg_node_pso", "avg_node_abc", "avg_node_ga"]
# for i, ffa, cpso, pso, ffao, ffa, pso, abc, ga in zip(
#     df_ffa['max_tour'].values, 
#     df_ffa[key_node].values, 
#     df_cpso[key_node].values, 
#     df_pso[key_node].values,
#     df_ffao[key_node].values,
#     df_ffa[key_node].values,
#     df_pso[key_node].values,
#     df_abc[key_node].values,
#     df_ga[key_node].values,
# ):
#     data_node.append([i,ffa,cpso,pso,ffao,ffa,pso,abc,ga])

# df_node = pd.DataFrame(data_node, columns=["max_tour"]+node_columns)
# df_node.plot(x='max_tour', y=node_columns, kind='line')

# plt.title('Max Tour - Node')
# plt.xlabel('max_tour')
# plt.ylabel('Avg Node')
# plt.legend(node_columns)
# plt.show()

# %%
data_day = []
day_columns = ["avg_day_ffa", "avg_day_pso"]
for i, ffa, pso in zip(
    df_pso_p1_c1_t1['max_tour'].values, 
    df_pso_p1_c1_t1[key_day].values, 
    df_ffa_p1_c1_t1[key_day].values,
):
    data_day.append([i,ffa,pso])

df_day = pd.DataFrame(data_day, columns=["max_tour"]+day_columns)
df_day.plot(x='max_tour', y=day_columns, kind='line', figsize=(8 ,5))

plt.title('Max Tour - Day')
plt.xlabel('max_tour')
plt.ylabel('Avg Days')
plt.legend(day_columns)
plt.show()

# %%
# data_day = []
# day_columns = ["avg_day_ffa", "avg_day_cpso", "avg_day_pso", "avg_day_ffao", "avg_day_ffa", "avg_day_pso", "avg_day_abc", "avg_day_ga"]
# for i, ffa, cpso, pso, ffao, ffa, pso, abc, ga in zip(
#     df_ffa['max_tour'].values, 
#     df_ffa[key_day].values, 
#     df_cpso[key_day].values, 
#     df_pso[key_day].values,
#     df_ffao[key_day].values,
#     df_ffa[key_day].values,
#     df_pso[key_day].values,
#     df_abc[key_day].values,
#     df_ga[key_day].values,
# ):
#     data_day.append([i,ffa,cpso,pso,ffao,ffa,pso,abc,ga])

# df_day = pd.DataFrame(data_day, columns=["max_tour"]+day_columns)
# df_day.plot(x='max_tour', y=day_columns, kind='line')

# plt.title('Max Tour - Day')
# plt.xlabel('max_tour')
# plt.ylabel('Avg Days')
# plt.legend(day_columns)
# plt.show()

# %%
data_fitness = []
fitness_columns = ["avg_fitness_ffa", "avg_fitness_pso"]
for i, ffa, pso in zip(
    df_pso_p1_c1_t1['max_tour'].values, 
    df_pso_p1_c1_t1[key_fitness].values, 
    df_ffa_p1_c1_t1[key_fitness].values,
):
    data_fitness.append([i,ffa,pso])

df_fitness = pd.DataFrame(data_fitness, columns=["max_tour"]+fitness_columns)
df_fitness.plot(x='max_tour', y=fitness_columns, kind='line', figsize=(8 ,5))

plt.title('Max Tour - Fitness')
plt.xlabel('max_tour')
plt.ylabel('Avg Fitness')
plt.legend(fitness_columns)
plt.show()

# %%
# data_fitness = []
# fitness_columns = ["avg_fitness_ffa", "avg_fitness_cpso", "avg_fitness_pso", "avg_fitness_ffao", "avg_fitness_ffa", "avg_fitness_pso", "avg_fitness_abc", "avg_fitness_ga"]
# for i, ffa, cpso, pso, ffao, ffa, pso, abc, ga in zip(
#     df_ffa['max_tour'].values, 
#     df_ffa[key_fitness].values, 
#     df_cpso[key_fitness].values, 
#     df_pso[key_fitness].values,
#     df_ffao[key_fitness].values,
#     df_ffa[key_fitness].values,
#     df_pso[key_fitness].values,
#     df_abc[key_fitness].values,
#     df_ga[key_fitness].values,
# ):
#     data_fitness.append([i,ffa,cpso,pso,ffao,ffa,pso,abc,ga])

# df_fitness = pd.DataFrame(data_fitness, columns=["max_tour"]+fitness_columns)
# df_fitness.plot(x='max_tour', y=fitness_columns, kind='line')

# plt.title('Max Tour - Fitness')
# plt.xlabel('max_tour')
# plt.ylabel('Avg Fitness')
# plt.legend(fitness_columns)
# plt.show()

# %%
data_time = []
time_columns = ["avg_time_ffa", "avg_time_pso"]
for i, ffa, pso in zip(
    df_ffa_p1_c1_t1['max_tour'].values, 
    df_ffa_p1_c1_t1[key_time].values, 
   df_pso_p1_c1_t1[key_time].values,
):
    data_time.append([i,ffa,pso])

df_time = pd.DataFrame(data_time, columns=["max_tour"]+time_columns)
df_time.plot(x='max_tour', y=time_columns, kind='line')

plt.title('Max Tour - Time')
plt.xlabel('max_tour')
plt.ylabel('Time (s)')
plt.legend(time_columns)
plt.show()

# %%
data_score = []
score_columns = ["score_ffa", "score_pso"]
for i, ffa, pso in zip(
    df_ffa_p1_c1_t1['max_tour'].values, 
    df_ffa_p1_c1_t1[key_score].values, 
    df_pso_p1_c1_t1[key_score].values,
):
    data_score.append([i,ffa,pso])

df_score = pd.DataFrame(data_score, columns=["max_tour"]+score_columns)
df_score.plot(x='max_tour', y=score_columns, kind='line')

plt.title('Max Tour - Score')
plt.xlabel('max_tour')
plt.ylabel('Score')
plt.legend(score_columns)
plt.show()
